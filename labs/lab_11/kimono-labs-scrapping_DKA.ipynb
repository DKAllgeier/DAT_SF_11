# %% [markdown]
# Web scraping with the Kimono Labs API
#
# https://www.kimonolabs.com/

# %% [markdown]
# ### Datasets we will explore -
#
# * https://news.ycombinator.com/jobs
# * http://sfbay.craigslist.org/search/apa
# * http://en.wikipedia.org/wiki/List_of_countries_by_past_and_future_population

# %%
import pandas as pd

# %%
import json
import urllib

# %%
import yaml
credentials = yaml.load(open('kimono_api_key.yaml'))
api_key = credentials['KIMONO_KEY']

# %%
# !cat kimono_api_key.yaml
# Out:
# KIMONO_KEY: YOUR API KEY

# %%
data = json.load(urllib.urlopen("https://www.kimonolabs.com/api/5ujg54qa?apikey=" + api_key))

# %%
data
# Out:
# {u'count': 28,
#  u'frequency': u'Manual Crawl',
#  u'lastrunstatus': u'success',
#  u'lastsuccess': u'Mon Jan 12 2015 03:43:55 GMT+0000 (UTC)',
#  u'name': u'Hackernews-Jobs',
#  u'newdata': True,
#  u'results': {u'collection1': [{u'site': u'(drchrono.com)',
#     u'title': {u'href': u'https://drchrono.com/jobs',
#      u'text': u'Django and iOS hackers needed to help fix healthcare \u2013 drchrono'},
#     u'updated_at': u'6 hours ago'},
#    {u'site': u'(github.com)',
#     u'title': {u'href': u'https://gist.github.com/aelaguiz/f4670bd016b7c7ac18ab',
#      u'text': u'Cratejoy (YC S13) \u2013 CratejoyIsHiring.js'},
#     u'updated_at': u'10 hours ago'},
#    {u'site': u'(streak.com)',
#     u'title': {u'href': u'https://www.streak.com/careers',
#      u'text': u'Build on Gmail \u2013 Streak (YC S11) Is Hiring Front End Devs'},
#     u'updated_at': u'1 day ago'},
#    {u'site': u'(angel.co)',
#     u'title': {u'href': u'https://angel.co/tule/jobs/45275-ios-engineer',
#      u'text': u'Tule (YC S14) \u2013 We help farmers produce more food with less water'},
#     u'updated_at': u'1 day ago'},
#    {u'site': u'(watsi.org)',
#     u'title': {u'href': u'http://blog.watsi.org/post/104423790956/watsi-is-hiring-a-design-lead',
#      u'text': u'Watsi is hiring a design lead'},
#     u'updated_at': u'2 days ago'},
#    {u'site': u'',
#     u'title': {u'href': u'https://news.ycombinator.com/item?id=8865249',
#      u'text': u'Airware (YC W13) is building commercial drones in downtown SF'},
#     u'updated_at': u'2 days ago'},
#    {u'site': u'',
#     u'title': {u'href': u'https://news.ycombinator.com/item?id=8864364',
#      u'text': u'Like Cascading? Stealth-mode big data startup is hiring founding engineer'},
#     u'updated_at': u'2 days ago'},
#    {u'site': u'(codecombat.com)',
#     u'title': {u'href': u'http://blog.codecombat.com/codecombat-is-hiring-chief-artisan',
#      u'text': u'CodeCombat (YC W14) is hiring a Chief Artisan (level builder)'},
#     u'updated_at': u'2 days ago'},
#    {u'site': u'(lever.co)',
#     u'title': {u'href': u'https://jobs.lever.co/kamcord/8ce5e4ab-4718-4310-a3a9-1e3e357a22cf?lever-source=hackernews',
#      u'text': u'Kamcord is looking for a Lead Designer'},
#     u'updated_at': u'2 days ago'},
#    {u'site': u'',
#     u'title': {u'href': u'https://news.ycombinator.com/item?id=8861587',
#      u'text': u'Transcriptic, a robotic cloud biology lab, is hiring scientists and engineers'},
#     u'updated_at': u'2 days ago'},
#    {u'site': u'',
#     u'title': {u'href': u'https://news.ycombinator.com/item?id=8861093',
#      u'text': u'MinoMonsters (YC W11) Is Hiring a QA/Junior Engineer'},
#     u'updated_at': u'2 days ago'},
#    {u'site': u'(lever.co)',
#     u'title': {u'href': u'https://jobs.lever.co/assembly/21461ca1-0f3a-416f-8330-3dd0a9640629',
#      u'text': u'Assembly (YC W12) Is Hiring a UI/Front-End Developer'},
#     u'updated_at': u'3 days ago'},
#    {u'site': u'(virool.com)',
#     u'title': {u'href': u'https://www.virool.com/jobs/position/8531',
#      u'text': u'Virool (YC S12) Is Hiring Software Engineers \u2013 Ruby on Rails'},
#     u'updated_at': u'3 days ago'},
#    {u'site': u'(lever.co)',
#     u'title': {u'href': u'https://jobs.lever.co/standardtreasury/c9cf2c41-e25c-4a8d-abec-8d79896013eb ',
#      u'text': u'Help Engineer an API-driven Bank at Standard Treasury (YC S13)'},
#     u'updated_at': u'3 days ago'},
#    {u'site': u'(embed.ly)',
#     u'title': {u'href': u'http://embed.ly/company/jobs#ml',
#      u'text': u'Join Embedly as a Machine Learning Engineer'},
#     u'updated_at': u'3 days ago'},
#    {u'site': u'(heapanalytics.com)',
#     u'title': {u'href': u'https://heapanalytics.com/jobs',
#      u'text': u'Heap (YC W13) is hiring engineers to build a new approach to analytics'},
#     u'updated_at': u'3 days ago'},
#    {u'site': u'(chartio.com)',
#     u'title': {u'href': u'https://chartio.com/jobs/software-engineer',
#      u'text': u'Chartio is hiring data-focused Python and JavaScript Engineers'},
#     u'updated_at': u'3 days ago'},
#    {u'site': u'(lever.co)',
#     u'title': {u'href': u'https://lever.co/jobs.html',
#      u'text': u'Join Lever to fix hiring \u2013 JavaScript and distributed systems engineers in SF'},
#     u'updated_at': u'3 days ago'},
#    {u'site': u'',
#     u'title': {u'href': u'https://news.ycombinator.com/item?id=8854906',
#      u'text': u'InfluxDB (YC W13) is hiring front-end developers (who love open-source) in SF'},
#     u'updated_at': u'3 days ago'},
#    {u'site': u'(gocardless.com)',
#     u'title': {u'href': u'https://gocardless.com/about#jobs',
#      u'text': u'GoCardless (YC S11) is hiring software engineers and designers in London'},
#     u'updated_at': u'4 days ago'},
#    {u'site': u'(lever.co)',
#     u'title': {u'href': u'https://jobs.lever.co/mattermark/d33cbedc-b0f2-41cf-9038-ca16b0d4d491',
#      u'text': u'Mattermark is hiring their first DevOps engineer'},
#     u'updated_at': u'4 days ago'},
#    {u'site': u'(greenhouse.io)',
#     u'title': {u'href': u'https://boards.greenhouse.io/quartzy/jobs/37639',
#      u'text': u'Quartzy (YC S11) Is Hiring an Email Marketing Manager'},
#     u'updated_at': u'4 days ago'},
#    {u'site': u'(angel.co)',
#     u'title': {u'href': u'https://angel.co/bop-fm/jobs/16609-lead-android-mobile-developer',
#      u'text': u'Music Lover? Join Us \u2013 Bop.fm (YC S13) Is Hiring a Lead Android Developer in SF'},
#     u'updated_at': u'4 days ago'},
#    {u'site': u'(lever.co)',
#     u'title': {u'href': u'https://jobs.lever.co/statuspageio/0a8a9e28-79e9-40f0-ab0a-69c6afa8a2d5',
#      u'text': u'StatusPage.io (YC S13) Is Hiring Rails Developers in SF, Denver'},
#     u'updated_at': u'4 days ago'},
#    {u'site': u'(rainforestqa.com)',
#     u'title': {u'href': u'https://www.rainforestqa.com/jobs',
#      u'text': u'Rainforest QA (YC S12) Is Hiring Engineers \u2013 SF and Remote'},
#     u'updated_at': u'4 days ago'},
#    {u'site': u'',
#     u'title': {u'href': u'https://news.ycombinator.com/item?id=8848814',
#      u'text': u'Screenleap (YC W12) Is Looking for a CTO'},
#     u'updated_at': u'4 days ago'},
#    {u'site': u'',
#     u'title': {u'href': u'https://news.ycombinator.com/item?id=8848130',
#      u'text': u'Shoptiques Is Hiring Senior Manager, Account Management'},
#     u'updated_at': u'5 days ago'},
#    {u'site': u'(clever.com)',
#     u'title': {u'href': u'https://clever.com/about/jobs#engineer-full-stack',
#      u'text': u'Help build the platform for 21st century education at Clever (YC S12)'},
#     u'updated_at': u'5 days ago'}]},
#  u'thisversionrun': u'Mon Jan 12 2015 03:43:40 GMT+0000 (UTC)',
#  u'thisversionstatus': u'success',
#  u'version': 2}

# %%
def get_hacker_news_jobs(api_key):
    """
    Creates list of top 50 movies by gross box office
    sales for a year with ratings and sales
    """
    
    title_text, title_url = [], []
    url = "https://www.kimonolabs.com/api/5ujg54qa?" + \
            "apikey={api_key}".format(api_key=api_key)
    
    data = json.load(urllib.urlopen(url))
# Iterate through json object to collect data
    for n in xrange(data['count']):
        n_text = data['results']['collection1'][n]['title']['text']
        n_url = data['results']['collection1'][n]['title']['href']
        title_text.append(n_text)
        title_url.append(n_url)
    
    data = pd.DataFrame({'title':title_text,'url':title_url})
    
    return data

# %%
get_hacker_news_jobs(api_key='6d9YOFeaM8AdNV7LynhlkpuWDsdX4FJ7')
# Out:
#                                                 title  \
# 0   Django and iOS hackers needed to help fix heal...
# 1             Cratejoy (YC S13) – CratejoyIsHiring.js
# 2   Build on Gmail – Streak (YC S11) Is Hiring Fro...
# 3   Tule (YC S14) – We help farmers produce more f...
# 4                       Watsi is hiring a design lead
# 5   Airware (YC W13) is building commercial drones...
# 6   Like Cascading? Stealth-mode big data startup ...
# 7   CodeCombat (YC W14) is hiring a Chief Artisan ...
# 8              Kamcord is looking for a Lead Designer
# 9   Transcriptic, a robotic cloud biology lab, is ...
# 10  MinoMonsters (YC W11) Is Hiring a QA/Junior En...
# 11  Assembly (YC W12) Is Hiring a UI/Front-End Dev...
# 12  Virool (YC S12) Is Hiring Software Engineers –...
# 13  Help Engineer an API-driven Bank at Standard T...
# 14        Join Embedly as a Machine Learning Engineer
# 15  Heap (YC W13) is hiring engineers to build a n...
# 16  Chartio is hiring data-focused Python and Java...
# 17  Join Lever to fix hiring – JavaScript and dist...
# 18  InfluxDB (YC W13) is hiring front-end develope...
# 19  GoCardless (YC S11) is hiring software enginee...
# 20   Mattermark is hiring their first DevOps engineer
# 21  Quartzy (YC S11) Is Hiring an Email Marketing ...
# 22  Music Lover? Join Us – Bop.fm (YC S13) Is Hiri...
# 23  StatusPage.io (YC S13) Is Hiring Rails Develop...
# 24  Rainforest QA (YC S12) Is Hiring Engineers – S...
# 25           Screenleap (YC W12) Is Looking for a CTO
# 26  Shoptiques Is Hiring Senior Manager, Account M...
# 27  Help build the platform for 21st century educa...
#
#                                                   url
# 0                           https://drchrono.com/jobs
# 1   https://gist.github.com/aelaguiz/f4670bd016b7c...
# 2                      https://www.streak.com/careers
# 3       https://angel.co/tule/jobs/45275-ios-engineer
# 4   http://blog.watsi.org/post/104423790956/watsi-...
# 5        https://news.ycombinator.com/item?id=8865249
# 6        https://news.ycombinator.com/item?id=8864364
# 7   http://blog.codecombat.com/codecombat-is-hirin...
# 8   https://jobs.lever.co/kamcord/8ce5e4ab-4718-43...
# 9        https://news.ycombinator.com/item?id=8861587
# 10       https://news.ycombinator.com/item?id=8861093
# 11  https://jobs.lever.co/assembly/21461ca1-0f3a-4...
# 12          https://www.virool.com/jobs/position/8531
# 13  https://jobs.lever.co/standardtreasury/c9cf2c4...
# 14                    http://embed.ly/company/jobs#ml
# 15                     https://heapanalytics.com/jobs
# 16         https://chartio.com/jobs/software-engineer
# 17                         https://lever.co/jobs.html
# 18       https://news.ycombinator.com/item?id=8854906
# 19                  https://gocardless.com/about#jobs
# 20  https://jobs.lever.co/mattermark/d33cbedc-b0f2...
# 21    https://boards.greenhouse.io/quartzy/jobs/37639
# 22  https://angel.co/bop-fm/jobs/16609-lead-androi...
# 23  https://jobs.lever.co/statuspageio/0a8a9e28-79...
# 24                  https://www.rainforestqa.com/jobs
# 25       https://news.ycombinator.com/item?id=8848814
# 26       https://news.ycombinator.com/item?id=8848130
# 27  https://clever.com/about/jobs#engineer-full-stack

# %% [markdown]
# ### Additional Resources
#
# http://help.kimonolabs.com/hc/en-us/articles/203489400-Tutorial-Retrieve-large-data-sets-with-more-than-2500-results
