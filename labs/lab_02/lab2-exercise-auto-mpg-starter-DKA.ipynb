# %%
# Standard imports for data analysis packages in Python
import pandas as pd
import numpy as np
import seaborn as sns  # for pretty layout of plots
import matplotlib.pyplot as plt

# This enables inline Plots
# %matplotlib inline

# %%
# Let's explore Auto Dataset comparing various vehicles
# Notice, how I have given the delimiter

auto_mpg = pd.read_csv('../data/auto_mpg.txt', delimiter="\t")

# %%
# Examine the first 5 rows - use head
auto_mpg.head(5)
# Out:
#    mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0   18          8           307        130    3504          12.0     70
# 1   15          8           350        165    3693          11.5     70
# 2   18          8           318        150    3436          11.0     70
# 3   16          8           304        150    3433          12.0     70
# 4   17          8           302        140    3449          10.5     70
#
#    origin                   car_name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# Examine last 5 rows - use tail
auto_mpg.tail(5)
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 393   27          4           140         86    2790          15.6     82
# 394   44          4            97         52    2130          24.6     82
# 395   32          4           135         84    2295          11.6     82
# 396   28          4           120         79    2625          18.6     82
# 397   31          4           119         82    2720          19.4     82
#
#      origin         car_name
# 393       1  ford mustang gl
# 394       2        vw pickup
# 395       1    dodge rampage
# 396       1      ford ranger
# 397       1       chevy s-10

# %%
# Examine info on dataset to check on the datatypes
auto_mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 398 entries, 0 to 397
# Data columns (total 10 columns):
# mpg             398 non-null float64
# cylinders       398 non-null int64
# displacement    398 non-null float64
# horsepower      392 non-null float64
# weight          398 non-null int64
# acceleration    398 non-null float64
# model           398 non-null int64
# origin          398 non-null int64
# car_name        398 non-null object
# hpimputed       398 non-null float64
# dtypes: float64(5), int64(4), object(1)

# %%
# What are the columns in the dataset?
auto_mpg.columns
# Out:
# Index([u'mpg', u'cylinders', u'displacement', u'horsepower', u'weight', u'acceleration', u'model', u'origin', u'car_name'], dtype='object')

# %%
# How many 4 Cylinder cars are in the dataset?
auto_mpg[auto_mpg.cylinders==4]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 14   24.0          4         113.0         95    2372          15.0     70
# 18   27.0          4          97.0         88    2130          14.5     70
# 19   26.0          4          97.0         46    1835          20.5     70
# 20   25.0          4         110.0         87    2672          17.5     70
# 21   24.0          4         107.0         90    2430          14.5     70
# 22   25.0          4         104.0         95    2375          17.5     70
# 23   26.0          4         121.0        113    2234          12.5     70
# 29   27.0          4          97.0         88    2130          14.5     71
# 30   28.0          4         140.0         90    2264          15.5     71
# 31   25.0          4         113.0         95    2228          14.0     71
# 32   25.0          4          98.0          ?    2046          19.0     71
# 46   22.0          4         140.0         72    2408          19.0     71
# 49   23.0          4         122.0         86    2220          14.0     71
# 50   28.0          4         116.0         90    2123          14.0     71
# 51   30.0          4          79.0         70    2074          19.5     71
# 52   30.0          4          88.0         76    2065          14.5     71
# 53   31.0          4          71.0         65    1773          19.0     71
# 54   35.0          4          72.0         69    1613          18.0     71
# 55   27.0          4          97.0         60    1834          19.0     71
# 56   26.0          4          91.0         70    1955          20.5     71
# 57   24.0          4         113.0         95    2278          15.5     72
# 58   25.0          4          97.5         80    2126          17.0     72
# 59   23.0          4          97.0         54    2254          23.5     72
# 60   20.0          4         140.0         90    2408          19.5     72
# 61   21.0          4         122.0         86    2226          16.5     72
# 76   18.0          4         121.0        112    2933          14.5     72
# 77   22.0          4         121.0         76    2511          18.0     72
# 78   21.0          4         120.0         87    2979          19.5     72
# 79   26.0          4          96.0         69    2189          18.0     72
# 80   22.0          4         122.0         86    2395          16.0     72
# ..    ...        ...           ...        ...     ...           ...    ...
# 358  31.6          4         120.0         74    2635          18.3     81
# 359  28.1          4         141.0         80    3230          20.4     81
# 367  28.0          4         112.0         88    2605          19.6     82
# 368  27.0          4         112.0         88    2640          18.6     82
# 369  34.0          4         112.0         88    2395          18.0     82
# 370  31.0          4         112.0         85    2575          16.2     82
# 371  29.0          4         135.0         84    2525          16.0     82
# 372  27.0          4         151.0         90    2735          18.0     82
# 373  24.0          4         140.0         92    2865          16.4     82
# 374  23.0          4         151.0          ?    3035          20.5     82
# 375  36.0          4         105.0         74    1980          15.3     82
# 376  37.0          4          91.0         68    2025          18.2     82
# 377  31.0          4          91.0         68    1970          17.6     82
# 378  38.0          4         105.0         63    2125          14.7     82
# 379  36.0          4          98.0         70    2125          17.3     82
# 380  36.0          4         120.0         88    2160          14.5     82
# 381  36.0          4         107.0         75    2205          14.5     82
# 382  34.0          4         108.0         70    2245          16.9     82
# 383  38.0          4          91.0         67    1965          15.0     82
# 384  32.0          4          91.0         67    1965          15.7     82
# 385  38.0          4          91.0         67    1995          16.2     82
# 388  26.0          4         156.0         92    2585          14.5     82
# 390  32.0          4         144.0         96    2665          13.9     82
# 391  36.0          4         135.0         84    2370          13.0     82
# 392  27.0          4         151.0         90    2950          17.3     82
# 393  27.0          4         140.0         86    2790          15.6     82
# 394  44.0          4          97.0         52    2130          24.6     82
# 395  32.0          4         135.0         84    2295          11.6     82
# 396  28.0          4         120.0         79    2625          18.6     82
# 397  31.0          4         119.0         82    2720          19.4     82
#
#      origin                      car_name
# 14        3         toyota corona mark ii
# 18        3                  datsun pl510
# 19        2  volkswagen 1131 deluxe sedan
# 20        2                   peugeot 504
# 21        2                   audi 100 ls
# 22        2                      saab 99e
# 23        2                      bmw 2002
# 29        3                  datsun pl510
# 30        1           chevrolet vega 2300
# 31        3                 toyota corona
# 32        1                    ford pinto
# 46        1           chevrolet vega (sw)
# 49        1            mercury capri 2000
# 50        2                     opel 1900
# 51        2                   peugeot 304
# 52        2                     fiat 124b
# 53        3           toyota corolla 1200
# 54        3                   datsun 1200
# 55        2          volkswagen model 111
# 56        1              plymouth cricket
# 57        3         toyota corona hardtop
# 58        1            dodge colt hardtop
# 59        2             volkswagen type 3
# 60        1                chevrolet vega
# 61        1           ford pinto runabout
# 76        2               volvo 145e (sw)
# 77        2           volkswagen 411 (sw)
# 78        2              peugeot 504 (sw)
# 79        2               renault 12 (sw)
# 80        1               ford pinto (sw)
# ..      ...                           ...
# 358       3                     mazda 626
# 359       2     peugeot 505s turbo diesel
# 367       1            chevrolet cavalier
# 368       1      chevrolet cavalier wagon
# 369       1     chevrolet cavalier 2-door
# 370       1    pontiac j2000 se hatchback
# 371       1                dodge aries se
# 372       1               pontiac phoenix
# 373       1          ford fairmont futura
# 374       1                amc concord dl
# 375       2           volkswagen rabbit l
# 376       3            mazda glc custom l
# 377       3              mazda glc custom
# 378       1        plymouth horizon miser
# 379       1                mercury lynx l
# 380       3              nissan stanza xe
# 381       3                  honda accord
# 382       3                toyota corolla
# 383       3                   honda civic
# 384       3            honda civic (auto)
# 385       3                 datsun 310 gx
# 388       1    chrysler lebaron medallion
# 390       3              toyota celica gt
# 391       1             dodge charger 2.2
# 392       1              chevrolet camaro
# 393       1               ford mustang gl
# 394       2                     vw pickup
# 395       1                 dodge rampage
# 396       1                   ford ranger
# 397       1                    chevy s-10
#
# [204 rows x 9 columns]

# %%
# Sort the dataset by mpg and show the last 5 rows.
auto_mpg.sort_index(by='mpg', ascending=False).tail(5)
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 103   11          8           400        150    4997          14.0     73
# 67    11          8           429        208    4633          11.0     72
# 25    10          8           360        215    4615          14.0     70
# 26    10          8           307        200    4376          15.0     70
# 28     9          8           304        193    4732          18.5     70
#
#      origin          car_name
# 103       1  chevrolet impala
# 67        1   mercury marquis
# 25        1         ford f250
# 26        1         chevy c20
# 28        1          hi 1200d

# %% [markdown]
# ### Missing Data

# %%
# Horsepower has missing data (marked as ?).  
# Can you set the value to Average horse power from other cars that have same number of Cylinders?
auto_mpg.horsepower.replace('?', np.nan, inplace=True)
auto_mpg.horsepower=auto_mpg.horsepower.astype(float)
auto_mpg[pd.isnull(auto_mpg.horsepower)]

auto_mpg.groupby('cylinders').horsepower.mean()
fill_grp_mean=lambda x: x.fillna(x.mean())
auto_mpg['hpimputed'] = auto_mpg.groupby('cylinders')['horsepower'].transform(fill_grp_mean)

auto_mpg[pd.isnull(auto_mpg.horsepower)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  model  \
# 32   25.0          4            98         NaN    2046          19.0     71
# 126  21.0          6           200         NaN    2875          17.0     74
# 330  40.9          4            85         NaN    1835          17.3     80
# 336  23.6          4           140         NaN    2905          14.3     80
# 354  34.5          4           100         NaN    2320          15.8     81
# 374  23.0          4           151         NaN    3035          20.5     82
#
#      origin              car_name   hpimputed
# 32        1            ford pinto   78.281407
# 126       1         ford maverick  101.506024
# 330       2  renault lecar deluxe   78.281407
# 336       1    ford mustang cobra   78.281407
# 354       2           renault 18i   78.281407
# 374       1        amc concord dl   78.281407

# %%
# Horsepower is marked as "object" datatype because of missing data - check using info()
# Now that you have filled the missing data, can you change the datatype to integer? - np.int64?
auto_mpg.hpimputed=auto_mpg.hpimputed.astype(int)
auto_mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 398 entries, 0 to 397
# Data columns (total 10 columns):
# mpg             398 non-null float64
# cylinders       398 non-null int64
# displacement    398 non-null float64
# horsepower      392 non-null float64
# weight          398 non-null int64
# acceleration    398 non-null float64
# model           398 non-null int64
# origin          398 non-null int64
# car_name        398 non-null object
# hpimputed       398 non-null int64
# dtypes: float64(4), int64(5), object(1)

# %% [markdown]
# ### Plotting

# %%
# Can you plot a histogram (bar chart) showing the number of cylinders on X Axis and count of cars on Y Axis?
auto_mpg.hpimputed.hist(bins=25)

# %%
# Now that horsepower is also a numeric field, plot a Scatter plot of miles-per-gallon and horsepower.
plt.scatter(auto_mpg.mpg, auto_mpg.hpimputed)

# %% [markdown]
# ### Challenge - Feature Extraction

# %%
# Can you separate the Car Company from car_name and count how many cars are in the dataset by car company?
# Assume the first word in car_name is the car company
# Out:
#   File "<ipython-input-71-c6d27084ec71>", line 4
#     for car_name in df
#                       ^
# SyntaxError: invalid syntax

# %%
# How many 4-6-8 cylinder cars are there in the dataset for each car company

# %% [markdown]
# ### Challenge - Model Intution

# %%
# Do you find any correlation between any of the variable?
# If you are building a Linear Model to predict "Miles-Per-Gallon", what are the features you would use?
