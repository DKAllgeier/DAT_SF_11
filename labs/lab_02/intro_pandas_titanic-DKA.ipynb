# %%
# Install seaborn
# If this line gives an error, go back to command prompt and run "conda install pip" and then try this step again
# !pip install seaborn
# Out:
# Requirement already satisfied (use --upgrade to upgrade): seaborn in /Users/danielallgeier/anaconda/lib/python2.7/site-packages
# Cleaning up...

# %%
# Standard imports for data analysis packages in Python
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import Image

# This enables inline Plots
# %matplotlib inline

# Limit rows displayed in notebook
pd.set_option('display.max_rows', 10)
pd.set_option('display.precision', 2)

# %%
print 'Pandas Version: ', pd.__version__
print 'Numpy Version: ', np.__version__
# Out:
# Pandas Version:  0.14.1
# Numpy Version:  1.9.0

# %% [markdown]
# # Pandas DataFrame
#
# Think of DataFrame as a Table with Columns.  This is the workhorse of everything you will do with data analysis.  Learning Pandas and its functions can be challenging, but stick with it and ask questions.
#
# Who uses Pandas - Almost everyone who uses Python for Data Analysis - Netflix, Airbnb, Uber, Meetup.com to name a few.

# %% [markdown]
# Kaggle Titanic Dataset:
# =======================
#
# * Source: http://www.kaggle.com/c/titanic-gettingStarted/data

# %%
# Let's explore Titanic Dataset
titanic = pd.read_csv('http://biostat.mc.vanderbilt.edu/wiki/pub/Main/DataSets/titanic3.csv')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-5-be907bd022d2> in <module>()
#       1 # Let's explore Titanic Dataset
# ----> 2 titanic = pd.read_csv('http://biostat.mc.vanderbilt.edu/wiki/pub/Main/DataSets/titanic3.csv')
#
# /Users/danielallgeier/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format)
#     450                     infer_datetime_format=infer_datetime_format)
#     451
# --> 452         return _read(filepath_or_buffer, kwds)
#     453
#     454     parser_f.__name__ = name
#
# /Users/danielallgeier/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     220
#     221     filepath_or_buffer, _ = get_filepath_or_buffer(filepath_or_buffer,
# --> 222                                                    encoding)
#     223
#     224     if kwds.get('date_parser', None) is not None:
#
# /Users/danielallgeier/anaconda/lib/python2.7/site-packages/pandas/io/common.pyc in get_filepath_or_buffer(filepath_or_buffer, encoding)
#     116
#     117     if _is_url(filepath_or_buffer):
# --> 118         req = _urlopen(str(filepath_or_buffer))
#     119         return maybe_read_encoded_stream(req, encoding)
#     120
#
# /Users/danielallgeier/anaconda/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout)
#     125     if _opener is None:
#     126         _opener = build_opener()
# --> 127     return _opener.open(url, data, timeout)
#     128
#     129 def install_opener(opener):
#
# /Users/danielallgeier/anaconda/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     408         for processor in self.process_response.get(protocol, []):
#     409             meth = getattr(processor, meth_name)
# --> 410             response = meth(req, response)
#     411
#     412         return response
#
# /Users/danielallgeier/anaconda/lib/python2.7/urllib2.pyc in http_response(self, request, response)
#     521         if not (200 <= code < 300):
#     522             response = self.parent.error(
# --> 523                 'http', request, response, code, msg, hdrs)
#     524
#     525         return response
#
# /Users/danielallgeier/anaconda/lib/python2.7/urllib2.pyc in error(self, proto, *args)
#     440             http_err = 0
#     441         args = (dict, proto, meth_name) + args
# --> 442         result = self._call_chain(*args)
#     443         if result:
#     444             return result
#
# /Users/danielallgeier/anaconda/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     380             func = getattr(handler, meth_name)
#     381
# --> 382             result = func(*args)
#     383             if result is not None:
#     384                 return result
#
# /Users/danielallgeier/anaconda/lib/python2.7/urllib2.pyc in http_error_302(self, req, fp, code, msg, headers)
#     624         # Don't close the fp until we are sure that we won't use it
#     625         # with HTTPError.
# --> 626         fp.read()
#     627         fp.close()
#     628
#
# /Users/danielallgeier/anaconda/lib/python2.7/socket.pyc in read(self, size)
#     349             while True:
#     350                 try:
# --> 351                     data = self._sock.recv(rbufsize)
#     352                 except error, e:
#     353                     if e.args[0] == EINTR:
#
# /Users/danielallgeier/anaconda/lib/python2.7/httplib.pyc in read(self, amt)
#     565         # connection, and the user is reading more bytes than will be provided
#     566         # (for example, reading in 1k chunks)
# --> 567         s = self.fp.read(amt)
#     568         if not s and amt:
#     569             # Ideally, we would raise IncompleteRead if the content-length
#
# /Users/danielallgeier/anaconda/lib/python2.7/socket.pyc in read(self, size)
#     378                 # fragmentation issues on many platforms.
#     379                 try:
# --> 380                     data = self._sock.recv(left)
#     381                 except error, e:
#     382                     if e.args[0] == EINTR:
#
# error: [Errno 54] Connection reset by peer

# %%
titanic.head(5)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#     age  sibsp  parch  ticket   fare    cabin embarked boat  body  \
# 0  29.0      0      0   24160  211.3       B5        S    2   NaN
# 1   0.9      1      2  113781  151.6  C22 C26        S   11   NaN
# 2   2.0      1      2  113781  151.6  C22 C26        S  NaN   NaN
# 3  30.0      1      2  113781  151.6  C22 C26        S  NaN   135
# 4  25.0      1      2  113781  151.6  C22 C26        S  NaN   NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
# Look at the Columns, data types, memory usage, null values
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
# pclass       1309 non-null int64
# survived     1309 non-null int64
# name         1309 non-null object
# sex          1309 non-null object
# age          1046 non-null float64
# sibsp        1309 non-null int64
# parch        1309 non-null int64
# ticket       1309 non-null object
# fare         1308 non-null float64
# cabin        295 non-null object
# embarked     1307 non-null object
# boat         486 non-null object
# body         121 non-null float64
# home.dest    745 non-null object
# dtypes: float64(3), int64(4), object(7)

# %%
# View Distribution
titanic.describe()
# Out:
#        pclass  survived     age   sibsp   parch    fare   body
# count  1309.0    1309.0  1046.0  1309.0  1309.0  1308.0  121.0
# mean      2.3       0.4    29.9     0.5     0.4    33.3  160.8
# std       0.8       0.5    14.4     1.0     0.9    51.8   97.7
# min       1.0       0.0     0.2     0.0     0.0     0.0    1.0
# 25%       2.0       0.0    21.0     0.0     0.0     7.9   72.0
# 50%       3.0       0.0    28.0     0.0     0.0    14.5  155.0
# 75%       3.0       1.0    39.0     1.0     0.0    31.3  256.0
# max       3.0       1.0    80.0     8.0     9.0   512.3  328.0

# %%
titanic.columns
# Out:
# Index([u'pclass', u'survived', u'name', u'sex', u'age', u'sibsp', u'parch', u'ticket', u'fare', u'cabin', u'embarked', u'boat', u'body', u'home.dest'], dtype='object')

# %%
titanic.rename(columns={'sex': 'gender'}, inplace=True)
#without inplace=True, it returns a new data frame instead of renaming

# %%
titanic.head(3)
# Out:
#    pclass  survived                            name  gender   age  sibsp  \
# 0       1         1   Allen, Miss. Elisabeth Walton  female  29.0      0
# 1       1         1  Allison, Master. Hudson Trevor    male   0.9      1
# 2       1         0    Allison, Miss. Helen Loraine  female   2.0      1
#
#    parch  ticket   fare    cabin embarked boat  body  \
# 0      0   24160  211.3       B5        S    2   NaN
# 1      2  113781  151.6  C22 C26        S   11   NaN
# 2      2  113781  151.6  C22 C26        S  NaN   NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON

# %%
# So What is a Pandas Dataframe
# What is a Pandas DataFrame
Image(filename='images/dataframe.png')

# %%
# show only that survived
titanic[titanic.survived == 1]

#titanic.survived==1
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1261       3         1                           Turkula, Mrs. (Hedwig)
# 1277       3         1                             Vartanian, Mr. David
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
#
#       gender   age  sibsp  parch  ticket   fare    cabin embarked   boat  \
# 0     female  29.0      0      0   24160  211.3       B5        S      2
# 1       male   0.9      1      2  113781  151.6  C22 C26        S     11
# 5       male  48.0      0      0   19952   26.6      E12        S      3
# 6     female  63.0      1      0   13502   78.0       D7        S     10
# 8     female  53.0      2      0   11769   51.5     C101        S      D
# ...      ...   ...    ...    ...     ...    ...      ...      ...    ...
# 1261  female  63.0      0      0    4134    9.6      NaN        S     15
# 1277    male  22.0      0      0    2658    7.2      NaN        C  13 15
# 1286  female  38.0      0      0    2688    7.2      NaN        C      C
# 1290  female  47.0      1      0  363272    7.0      NaN        S    NaN
# 1300  female  15.0      1      0    2659   14.5      NaN        C    NaN
#
#       body                        home.dest
# 0      NaN                     St Louis, MO
# 1      NaN  Montreal, PQ / Chesterville, ON
# 5      NaN                     New York, NY
# 6      NaN                       Hudson, NY
# 8      NaN              Bayside, Queens, NY
# ...    ...                              ...
# 1261   NaN                              NaN
# 1277   NaN                              NaN
# 1286   NaN                              NaN
# 1290   NaN                              NaN
# 1300   NaN                              NaN
#
# [500 rows x 14 columns]

# %%
# unique values
titanic.gender.unique()

# also works as titanic['gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
# How many Survived?
titanic['survived'].value_counts()
# Out:
# 0    809
# 1    500
# dtype: int64

# %%
titanic.info()
#age has missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
# pclass       1309 non-null int64
# survived     1309 non-null int64
# name         1309 non-null object
# gender       1309 non-null object
# age          1046 non-null float64
# sibsp        1309 non-null int64
# parch        1309 non-null int64
# ticket       1309 non-null object
# fare         1308 non-null float64
# cabin        295 non-null object
# embarked     1307 non-null object
# boat         486 non-null object
# body         121 non-null float64
# home.dest    745 non-null object
# dtypes: float64(3), int64(4), object(7)

# %%
# Let's identify the missing age rows 
titanic.age[pd.isnull(titanic.age)]
# Out:
# 15   NaN
# 37   NaN
# 40   NaN
# ...
# 1302   NaN
# 1303   NaN
# 1305   NaN
# Name: age, Length: 263, dtype: float64

# %%
titanic.age.mean()
# Out:
# 29.881137667304014

# %%
# Age - fix null values
titanic.age.fillna(titanic.age.mean())

'''titanic['age_imputed']=titanic.age.fillna(titanic.age.mean())
titanic.head(5)

np.random.normal(20, 100, 293)
#creates 293 randomly distributed values between 20 and 100'''
# Out:
#    pclass  survived                                             name  gender  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#     age  sibsp  parch  ticket   fare    cabin embarked boat  body  \
# 0  29.0      0      0   24160  211.3       B5        S    2   NaN
# 1   0.9      1      2  113781  151.6  C22 C26        S   11   NaN
# 2   2.0      1      2  113781  151.6  C22 C26        S  NaN   NaN
# 3  30.0      1      2  113781  151.6  C22 C26        S  NaN   135
# 4  25.0      1      2  113781  151.6  C22 C26        S  NaN   NaN
#
#                          home.dest  age_imputed
# 0                     St Louis, MO         29.0
# 1  Montreal, PQ / Chesterville, ON          0.9
# 2  Montreal, PQ / Chesterville, ON          2.0
# 3  Montreal, PQ / Chesterville, ON         30.0
# 4  Montreal, PQ / Chesterville, ON         25.0

# %%
# Did the inplace get us again?

# %%
# Distribution of Age
titanic.age.hist(bins=50)
#courtesy of seaborn. Bins breaks up range into indicated number of categories

# %%
# Distribution of Age by Gender
titanic.age.hist(by=titanic['gender']);

# %%
# They look the same, buy see that y-axis is not the same
titanic.age.hist(by=titanic['gender'], sharey=True);
#compare using same scale

# %%
# Did your gender make a difference in survival
titanic.gender.value_counts()
# Out:
# male      843
# female    466
# dtype: int64

# %%
Image(filename='images/wesm_book_groupby.png')

# %%
# Groupby
titanic.groupby(['pclass', 'gender'])['survived'].agg(['sum', 'count'])

#can also check 'mean'
# Out:
#                sum  count
# pclass gender
# 1      female  139    144
#        male     61    179
# 2      female   94    106
#        male     25    171
# 3      female  106    216
#        male     75    493

# %%
# Show how many survivied by gender and class
class_gender_group = titanic.groupby(['pclass', 'gender'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-57189e7e9c70> in <module>()
#       1 # Show how many survivied by gender and class
# ----> 2 class_gender_group = titanic.groupby(['pclass', 'gender'])
#
# NameError: name 'titanic' is not defined

# %%
class_gender_group

# %%
for k, group in class_gender_group:
    print (k)
# Out:
# (1, 'female')
# (1, 'male')
# (2, 'female')
# (2, 'male')
# (3, 'female')
# (3, 'male')

# %%
# Plot how many survived, by gender and class
grid_plot = sns.FacetGrid(titanic, row='gender', col='pclass')
grid_plot.map(sns.regplot, 'survived', 'age',color='.3', fit_reg=False, x_jitter=.1)

# %%
ax = sns.boxplot(titanic.age, groupby=titanic.pclass)
ax.set_title('Age Distribution by class')

# %%
# Who paid the highest Fare in Titanic.  Did they survive?
titanic.sort_index(by='fare', ascending=False)

# %%
# Custom Translation of Values and creating new Columns
def gender_map(val):
    if val == 'male':
        return 1
    return 0
titanic['gender_val'] = titanic.gender.map(gender_map)

# %%
titanic.head()

# %%
# Some mistakes I made when learning to work with Pandas
# Don't use Loop to update Dataframe
for k, row in titanic.iterrows():
    if row.gender == 'male':
        titanic.ix[k, 'gender_val'] = 5
    else:
        titanic.ix[k, 'gender_val'] = 6

# %%
titanic.head()

# %%
# Filtering Gotchas
titanic[(titanic.survived == 1) & (titanic.pclass == 1)]

# %%
# Let's now look at Distribution of Age and Survived
# Now look at survived data
g = sns.FacetGrid(titanic, row='gender', col='survived', sharex=True, sharey=True)
g.map(plt.hist, "age")

# %%
# Now, your turn - Can you do some plots with pclass (Passenger Class)
