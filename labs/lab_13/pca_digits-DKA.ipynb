# %% [markdown]
# #Lab - Principal Component Analysis
# In this lab we will investigate PCA applications.
#
# Credit: this notebook is updated and adapted from a tutorial by [Andreas Mueller](https://twitter.com/t3kcit).

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize
# %matplotlib inline
figsize(12,5)

# %% [markdown]
# The code below will generate a random normally distributed matrix with the given covariance.

# %%
Cov = np.array([[2, -2], [-2, 3]])
X = np.random.multivariate_normal([1,2], Cov, size=200)

# %%
np.set_printoptions(4, suppress=True) # show only four decimals
print X[:10,:] # print the first 10 rows of X (from 0 to 9)
# Out:
# [[ 4.1766 -2.7226]
#  [-1.0486  3.8885]
#  [-0.3217  3.1153]
#  [ 1.1735  1.6597]
#  [ 1.8495  2.2611]
#  [ 0.377   3.7644]
#  [ 1.478   1.365 ]
#  [ 0.3247  3.5135]
#  [ 1.9167  2.6104]
#  [ 2.2776  0.0177]]

# %%
_ = plt.scatter(X[:,0], X[:,1])

# %% [markdown]
# Good linear fit?
#
# Let's look at the actual covariance matrix:

# %%
print np.cov(X,rowvar=False)
# Out:
# [[ 2.1865 -2.3622]
#  [-2.3622  3.463 ]]

# %% [markdown]
# ##PCA
#
# `sklearn.decomposition.PCA` implements `fit` and `transform` methods which do the following:
#
# 1. place the point cloud in the center (0,0) and
# 2. rotate it, such that the direction with most variance is parallel to the x-axis.

# %%
from sklearn.decomposition import PCA
pca = PCA()

# %%
X_pca = pca.fit_transform(X)

# %%
pca.components_
# Out:
# array([[-0.6079,  0.794 ],
#        [ 0.794 ,  0.6079]])

# %%
pca.mean_
# Out:
# array([ 0.9992,  1.9869])

# %% [markdown]
# Let's look the resulting, transformed data

# %%
_ = plt.scatter(X_pca[:,0], X_pca[:,1])

# %% [markdown]
# ###Q: What is the covariances between these two axes?

# %%
print np.cov(X_pca, rowvar=False)
# Out:
# [[ 5.2717 -0.    ]
#  [-0.      0.3779]]

# %% [markdown]
# ##Technique: High Dimensional Analysis
# PCA can be used to recover signals in noise.

# %%
np.random.seed(1)
X_HD = np.dot(X,np.random.uniform(0.2,3,(2,4))*(np.random.randint(0,2,(2,4))*2-1))

# %%
import pandas as pd

# %%
hd_df = pd.DataFrame(X_HD)

# %%
hd_df
# Out:
#             0         1         2         3
# 0   -4.048873  8.010660  1.127777 -1.192103
# 1   -0.941500 -0.541477 -2.595647 -3.442795
# 2   -1.463157  0.715255 -2.183316 -3.300608
# 3   -2.618919  3.362618 -1.432630 -3.165975
# 4   -3.910803  5.136928 -2.001957 -4.575552
# 5   -2.815338  2.561919 -2.791651 -4.789749
# 6   -2.855292  3.902490 -1.280955 -3.140492
# 7   -2.590543  2.330959 -2.600129 -4.442065
# 8   -4.216152  5.446185 -2.267421 -5.053710
# 9   -3.125740  5.057266 -0.468994 -2.404180
# 10  -2.455947  1.798710 -2.953753 -4.752606
# 11  -4.033152  8.143421  1.318183 -0.971717
# 12  -3.900865  6.088306 -0.850455 -3.294080
# 13  -3.142684  4.215391 -1.504858 -3.561788
# 14  -1.221373  1.103378 -1.220672 -2.088535
# 15  -2.845763  4.009324 -1.134206 -2.972199
# 16  -1.957630  1.210129 -2.620245 -4.082726
# 17  -2.548725  3.925105 -0.618473 -2.221837
# 18  -1.357107  2.089128 -0.330329 -1.184173
# 19  -3.274090  6.162695  0.537454 -1.378821
# 20  -3.475426  5.842014 -0.261165 -2.384821
# 21  -3.232014  5.046084 -0.702621 -2.727040
# 22  -2.065704  2.589207 -1.205009 -2.580282
# 23  -1.179096  0.014520 -2.427339 -3.399627
# 24  -3.727325  5.407773 -1.299603 -3.686948
# 25  -2.748956  2.941405 -2.202928 -4.097615
# 26  -2.222616  0.596974 -3.898491 -5.658371
# 27  -3.172645  4.623809 -1.081489 -3.110902
# 28  -3.283087  3.524666 -2.617014 -4.878342
# 29  -3.382909  4.929079 -1.154554 -3.318615
# ..        ...       ...       ...       ...
# 170 -2.640019  2.540216 -2.453962 -4.309992
# 171 -3.731828  5.155777 -1.608486 -4.031803
# 172 -1.777705  2.278131 -0.977681 -2.154827
# 173 -3.310054  5.064833 -0.842134 -2.928629
# 174 -3.597620  6.175350 -0.118274 -2.300224
# 175 -4.481921  9.021815  1.431901 -1.116345
# 176 -4.650289  6.741585 -1.627672 -4.606849
# 177 -3.056278  5.545158  0.254975 -1.560382
# 178 -3.493225  4.300948 -2.129925 -4.465515
# 179 -1.221702 -0.132605 -2.690561 -3.716878
# 180 -2.760654  4.950873  0.161463 -1.485712
# 181 -3.540479  5.769926 -0.481730 -2.668358
# 182 -0.877086 -1.539585 -3.648545 -4.570216
# 183 -2.431916  1.922514 -2.756765 -4.519919
# 184 -2.637563  2.784304 -2.158725 -3.981487
# 185 -0.651403 -0.496282 -1.940471 -2.542163
# 186 -1.034090 -0.219331 -2.404679 -3.287095
# 187  0.461843 -2.350508 -1.836507 -1.755764
# 188 -3.064619  4.058049 -1.530038 -3.542609
# 189 -2.103153  2.937190 -0.869008 -2.230685
# 190 -0.235233 -1.722930 -2.535743 -2.950593
# 191 -1.365460 -0.221383 -3.094142 -4.250591
# 192 -2.854607  4.900597 -0.093092 -1.824324
# 193 -3.284697  5.630598 -0.117041 -2.110178
# 194 -2.869186  4.424760 -0.688942 -2.493118
# 195 -3.706449  6.516147  0.061198 -2.167049
# 196 -0.566163  0.557740 -0.510833 -0.907206
# 197 -3.263472  3.537323 -2.561300 -4.804803
# 198 -2.030475  1.862926 -1.995297 -3.434415
# 199 -0.278947 -0.424683 -1.083155 -1.367967
#
# [200 rows x 4 columns]

# %% [markdown]
# We have actually investigated the idea of PCA visually, using scatter matrix

# %%
_ = pd.scatter_matrix(hd_df,diagonal='kde')

# %% [markdown]
# Stare at this long enough and you will realize this 4-dimensional data set is actually only 2-dimensions under the hood.
#
# ...Or, we could just use PCA

# %%
X_HE = pca.fit_transform(X_HD)
print X_HE[:10,:]
# Out:
# [[-5.7362 -2.3366  0.     -0.    ]
#  [ 4.1256 -0.2223  0.     -0.    ]
#  [ 2.6985 -0.2933  0.      0.    ]
#  [-0.2886 -0.2331  0.     -0.    ]
#  [-2.1151  1.7142  0.     -0.    ]
#  [ 0.8     1.7615  0.      0.    ]
#  [-0.8975 -0.2183  0.      0.    ]
#  [ 1.0185  1.2992  0.     -0.    ]
#  [-2.4063  2.3491  0.     -0.    ]
#  [-2.2797 -1.0536  0.      0.    ]]

# %% [markdown]
# So we have projected all 4 dimensions onto only 2 dimensions.

# %%
plt.scatter(X_HE[:,0], X_HE[:,1])

# %%
he_df = pd.DataFrame(X_HE)
_ = pd.scatter_matrix(he_df,diagonal='kde')

# %% [markdown]
# ## Technique - Dimensionality Reduction
# The underlying signal in our 4-dimensional data set is 2-dimensional (2 signal features and 2 noise features), so we can toss out 2 dimensions and exactly recover the signal, but this is not usually the case in real data (where all features have some signal AND some noise).
#
# SO, can we reduce the dimensionality even more and still reconstruct our signal?

# %%
X_HD*100
# Out:
# array([[-404.8873,  801.066 ,  112.7777, -119.2103],
#        [ -94.15  ,  -54.1477, -259.5647, -344.2795],
#        [-146.3157,   71.5255, -218.3316, -330.0608],
#        [-261.8919,  336.2618, -143.263 , -316.5975],
#        [-391.0803,  513.6928, -200.1957, -457.5552],
#        [-281.5338,  256.1919, -279.1651, -478.9749],
#        [-285.5292,  390.249 , -128.0955, -314.0492],
#        [-259.0543,  233.0959, -260.0129, -444.2065],
#        [-421.6152,  544.6185, -226.7421, -505.371 ],
#        [-312.574 ,  505.7266,  -46.8994, -240.418 ],
#        [-245.5947,  179.871 , -295.3753, -475.2606],
#        [-403.3152,  814.3421,  131.8183,  -97.1717],
#        [-390.0865,  608.8306,  -85.0455, -329.408 ],
#        [-314.2684,  421.5391, -150.4858, -356.1788],
#        [-122.1373,  110.3378, -122.0672, -208.8535],
#        [-284.5763,  400.9324, -113.4206, -297.2199],
#        [-195.763 ,  121.0129, -262.0245, -408.2726],
#        [-254.8725,  392.5105,  -61.8473, -222.1837],
#        [-135.7107,  208.9128,  -33.0329, -118.4173],
#        [-327.409 ,  616.2695,   53.7454, -137.8821],
#        [-347.5426,  584.2014,  -26.1165, -238.4821],
#        [-323.2014,  504.6084,  -70.2621, -272.704 ],
#        [-206.5704,  258.9207, -120.5009, -258.0282],
#        [-117.9096,    1.452 , -242.7339, -339.9627],
#        [-372.7325,  540.7773, -129.9603, -368.6948],
#        [-274.8956,  294.1405, -220.2928, -409.7615],
#        [-222.2616,   59.6974, -389.8491, -565.8371],
#        [-317.2645,  462.3809, -108.1489, -311.0902],
#        [-328.3087,  352.4666, -261.7014, -487.8342],
#        [-338.2909,  492.9079, -115.4554, -331.8615],
#        [-119.7337,  -18.4023, -270.1165, -371.3934],
#        [-215.4619,  169.1718, -245.6197, -401.9792],
#        [-380.7881,  533.7119, -155.0604, -401.3546],
#        [-294.5519,  323.5692, -226.0642, -428.0062],
#        [-257.5274,  311.7722, -163.3248, -336.1877],
#        [-293.7692,  284.3618, -271.0471, -477.3603],
#        [-164.3146,  235.4771,  -60.7601, -166.3768],
#        [-427.3484,  762.3126,   20.1434, -235.3612],
#        [ -55.1957, -131.5417, -270.7993, -333.2359],
#        [ -65.2379,  -43.442 , -186.8959, -246.354 ],
#        [-212.5775,  154.7858, -256.7401, -412.5577],
#        [-222.7924,  342.4833,  -54.8033, -195.0383],
#        [-311.6437,  407.1929, -162.0972, -367.4578],
#        [-186.4282,  207.8753, -139.418 , -266.8371],
#        [-245.8386,  344.3506, -100.365 , -259.4014],
#        [-174.6036,  183.6789, -143.6643, -264.4108],
#        [-502.8668,  660.8819, -256.9978, -587.8756],
#        [-327.5537,  405.9534, -196.5565, -415.2202],
#        [-121.0181,    2.5094, -247.9217, -347.5833],
#        [ -37.2669, -134.4014, -237.0272, -285.0174],
#        [-476.3164,  756.0118,  -88.8709, -385.6384],
#        [-198.8257,  224.9394, -144.8375, -280.3152],
#        [-122.7028,   28.2427, -220.8255, -318.5856],
#        [-292.3176,  408.956 , -119.9329, -309.101 ],
#        [-434.8928,  785.5493,   32.1231, -226.6407],
#        [-213.8925,  157.9027, -255.7615, -412.2666],
#        [-359.4938,  446.1379, -215.0102, -454.9193],
#        [-432.6033,  552.0434, -240.6974, -527.4542],
#        [ -41.6542, -133.8893, -245.5146, -297.0639],
#        [-180.5218,   90.8021, -266.3367, -403.8592],
#        [ -89.1041,  -80.3448, -280.2434, -364.1421],
#        [-116.5472,  104.6697, -117.2148, -200.108 ],
#        [-210.3246,  334.2826,  -38.7022, -169.6861],
#        [-252.4058,  361.897 ,  -93.1234, -255.3399],
#        [-222.8775,   20.621 , -437.576 , -619.074 ],
#        [-385.9356,  624.4432,  -57.8809, -296.8159],
#        [ -87.7104, -113.5216, -316.7911, -403.7845],
#        [-418.6944,  682.9654,  -56.2341, -314.744 ],
#        [-243.1513,  325.2413, -117.5086, -276.7705],
#        [-271.9996,  428.9628,  -54.026 , -223.8472],
#        [-185.1671,  274.1619,  -58.0087, -175.9024],
#        [-199.328 ,  318.0477,  -35.2015, -159.178 ],
#        [-367.0485,  533.7081, -126.5789, -361.5222],
#        [-382.2087,  607.7695,  -69.974 , -307.9639],
#        [-303.6553,  298.3476, -274.9188, -487.6097],
#        [-237.9974,  340.4556,  -88.7379, -241.7945],
#        [-303.098 ,  328.5309, -237.8848, -446.2524],
#        [-274.9741,  285.3424, -230.9138, -421.5734],
#        [ -63.2554,  -57.6564, -199.6822, -259.3215],
#        [-156.5863,  168.0097, -124.9352, -232.8016],
#        [-150.9239,  155.6038, -127.9424, -232.7183],
#        [ -40.8245, -124.0968, -232.1541, -281.7647],
#        [-254.1621,  334.1411, -129.7578, -296.9775],
#        [-333.8035,  419.6906, -193.1846, -415.2537],
#        [ -95.3593,   57.3813, -129.4979, -200.9381],
#        [-322.5316,  519.7668,  -50.8549, -250.8035],
#        [-270.379 ,  292.8517, -212.4607, -398.3628],
#        [-139.0684,  205.9501,  -43.5162, -132.0539],
#        [-150.9324,   59.428 , -242.2836, -359.3753],
#        [-426.9651,  620.4517, -147.6914, -421.035 ],
#        [-203.5951,  138.2747, -257.7437, -408.2534],
#        [-330.7713,  354.7163, -264.1327, -492.0122],
#        [-162.1302,  207.1413,  -89.9138, -197.3522],
#        [-309.0607,  486.5887,  -62.3645, -255.4299],
#        [-308.3242,  279.3538, -307.1766, -526.1558],
#        [-266.1231,  259.8704, -242.8416, -429.4485],
#        [-330.27  ,  354.1843, -263.7259, -491.2593],
#        [-351.6615,  488.0807, -148.9145, -376.9848],
#        [-274.0177,  211.2103, -317.0516, -516.4086],
#        [-155.4217,   61.5303, -249.0923, -369.6239],
#        [-296.6714,  373.0271, -171.6682, -369.0316],
#        [-276.4362,  310.1297, -204.4807, -393.1759],
#        [-308.8984,  362.0312, -210.0889, -418.9613],
#        [-333.4049,  337.8373, -289.6571, -521.8726],
#        [-264.61  ,  288.6641, -205.4778, -387.1496],
#        [-164.5033,  195.4921, -108.6813, -219.5712],
#        [-198.7873,  228.9475, -139.9933, -274.9263],
#        [-121.5148,   54.2374, -187.4628, -280.9145],
#        [ -22.1742, -127.6946, -197.7633, -232.4258],
#        [-210.593 ,  187.5039, -213.7337, -363.7244],
#        [-331.1809,  491.6431, -102.2177, -312.9114],
#        [-212.9158,   62.47  , -367.1769, -535.0888],
#        [-343.9432,  412.5294, -222.7198, -454.0826],
#        [-414.3376,  818.5601,  113.9797, -123.5769],
#        [-245.4178,  391.7675,  -43.1284, -195.7487],
#        [ -88.1003, -141.7182, -351.1166, -442.0407],
#        [-258.9398,  334.369 , -139.3926, -310.5304],
#        [-232.6395,  289.8506, -137.7834, -292.8899],
#        [-173.2959,   23.7041, -331.1143, -471.2543],
#        [-149.7345,  111.8405, -177.4978, -286.892 ],
#        [-633.1727,  980.7065, -146.9847, -544.5868],
#        [-324.3411,  483.7083,  -97.4689, -303.5273],
#        [-416.7756,  620.9922, -125.9231, -390.7791],
#        [-354.2239,  380.0603, -282.6304, -526.6425],
#        [-322.8389,  491.7343,  -84.8141, -288.6042],
#        [-150.1627,  132.4453, -153.8927, -261.0036],
#        [ -35.4772, -195.3425, -305.757 , -360.0679],
#        [-209.4978,  165.509 , -237.6085, -389.5093],
#        [ -76.4685, -106.5185, -285.1589, -361.9682],
#        [-407.3912,  785.3713,   88.93  , -147.1352],
#        [-399.0239,  685.1691,  -12.832 , -254.8085],
#        [-501.2686,  830.9797,  -51.4898, -359.2777],
#        [-395.7016,  575.5072, -136.2987, -389.5651],
#        [-329.2777,  469.0484, -125.1301, -337.1432],
#        [-288.7217,  372.2769, -156.0779, -346.9695],
#        [-191.7261,  169.5193, -195.9956, -332.7005],
#        [-318.7786,  393.7156, -192.9103, -405.8905],
#        [-374.5592,  512.2417, -167.6678, -411.5635],
#        [-248.8495,  309.8382, -147.6321, -313.5729],
#        [-511.9552,  871.855 ,  -25.0578, -336.4435],
#        [-358.8657,  478.65  , -175.0611, -410.2904],
#        [-284.8558,  402.4305, -112.2193, -296.0578],
#        [-287.8213,  266.7466, -279.6544, -483.308 ],
#        [-121.2239,  152.0872,  -70.5462, -151.2347],
#        [-160.9779,  102.6589, -211.7225, -331.5808],
#        [-394.3347,  711.4783,   28.1635, -206.5717],
#        [ -51.8262, -183.1919, -325.2097, -391.4728],
#        [ -41.6305, -249.2361, -382.5776, -448.8697],
#        [-244.9627,  298.3465, -153.2339, -317.4343],
#        [-555.748 ,  984.0634,   17.5289, -315.6768],
#        [-258.4654,  338.8142, -133.1251, -303.3021],
#        [-401.8824,  498.3276, -240.8561, -509.1066],
#        [-169.6592,  169.7453, -149.976 , -268.4207],
#        [-154.3923,   58.2355, -250.8746, -370.9775],
#        [-297.2333,  382.8333, -161.1765, -357.7491],
#        [-163.6473,  227.9519,  -68.3217, -174.3502],
#        [-378.4801,  490.8779, -201.1919, -451.0612],
#        [-203.2566,  224.6702, -154.3441, -293.517 ],
#        [-131.3104,  -60.7247, -344.4266, -460.6844],
#        [-146.9844,  189.1116,  -79.9442, -177.177 ],
#        [-299.8891,  438.1278, -100.9543, -292.6443],
#        [-426.7872,  617.2897, -151.0811, -424.6824],
#        [-191.9874,  258.4985,  -90.7681, -216.3011],
#        [-487.1878,  757.2852, -109.8966, -415.4827],
#        [-149.0848,  -31.7366, -346.8201, -474.0529],
#        [-259.3994,  -35.9241, -580.5111, -799.4196],
#        [-350.887 ,  498.7162, -134.6664, -360.7357],
#        [-220.3257,  186.6367, -234.9432, -393.0859],
#        [-404.174 ,  418.2138, -340.8383, -621.2351],
#        [-368.2388,  532.6707, -130.2799, -366.3393],
#        [-264.0019,  254.0216, -245.3962, -430.9992],
#        [-373.1828,  515.5777, -160.8486, -403.1803],
#        [-177.7705,  227.8131,  -97.7681, -215.4827],
#        [-331.0054,  506.4833,  -84.2134, -292.8629],
#        [-359.762 ,  617.535 ,  -11.8274, -230.0224],
#        [-448.1921,  902.1815,  143.1901, -111.6345],
#        [-465.0289,  674.1585, -162.7672, -460.6849],
#        [-305.6278,  554.5158,   25.4975, -156.0382],
#        [-349.3225,  430.0948, -212.9925, -446.5515],
#        [-122.1702,  -13.2605, -269.0561, -371.6878],
#        [-276.0654,  495.0873,   16.1463, -148.5712],
#        [-354.0479,  576.9926,  -48.173 , -266.8358],
#        [ -87.7086, -153.9585, -364.8545, -457.0216],
#        [-243.1916,  192.2514, -275.6765, -451.9919],
#        [-263.7563,  278.4304, -215.8725, -398.1487],
#        [ -65.1403,  -49.6282, -194.0471, -254.2163],
#        [-103.409 ,  -21.9331, -240.4679, -328.7095],
#        [  46.1843, -235.0508, -183.6507, -175.5764],
#        [-306.4619,  405.8049, -153.0038, -354.2609],
#        [-210.3153,  293.719 ,  -86.9008, -223.0685],
#        [ -23.5233, -172.293 , -253.5743, -295.0593],
#        [-136.546 ,  -22.1383, -309.4142, -425.0591],
#        [-285.4607,  490.0597,   -9.3092, -182.4324],
#        [-328.4697,  563.0598,  -11.7041, -211.0178],
#        [-286.9186,  442.476 ,  -68.8942, -249.3118],
#        [-370.6449,  651.6147,    6.1198, -216.7049],
#        [ -56.6163,   55.774 ,  -51.0833,  -90.7206],
#        [-326.3472,  353.7323, -256.13  , -480.4803],
#        [-203.0475,  186.2926, -199.5297, -343.4415],
#        [ -27.8947,  -42.4683, -108.3155, -136.7967]])

# %%
#projecting on to one dimension
#actually creating a good bit of error since we know there are 2 important factors
pca = PCA(1)
X_E = pca.fit_transform(X_HD)
print X_E[:10,:]
# Out:
# [[-5.7362]
#  [ 4.1256]
#  [ 2.6985]
#  [-0.2886]
#  [-2.1151]
#  [ 0.8   ]
#  [-0.8975]
#  [ 1.0185]
#  [-2.4063]
#  [-2.2797]]

# %% [markdown]
# Reconstructing data from PCA requires applying the inverse transform (luckily, there's a method for that):

# %%
#reconstructed data is in blue, original data in red
X_reconstructed = pca.inverse_transform(X_E)
for i in xrange(4):
    for j in xrange(4):
        plt.subplot(4, 4, i * 4 + j + 1)
        plt.scatter(X_HD[:,i], X_HD[:,j],c='r')
        plt.scatter(X_reconstructed[:,i], X_reconstructed[:,j],c='b')
        plt.axis('equal')

# %% [markdown]
# ##Application - Image analysis
# This is PCA on truly high dimensional data

# %%
from sklearn.datasets import fetch_mldata
from sklearn.cluster import KMeans
from sklearn.utils import shuffle

# %%
from sklearn.datasets import load_digits

# %%
X_digits, _,_, y_digits = fetch_mldata("MNIST Original").values() 
X_digits, y_digits = shuffle(X_digits,y_digits) 
X_digits = X_digits[-5000:]

# %% [markdown]
# Let's have a look at some of the instances in the dataset we just loaded:

# %%
def plot_mnist_image_matrix(data,size):
    plt.rc("image", cmap="binary")
    for i in xrange(size[0]*size[1]):
        plt.subplot(size[0],size[1],i+1)
        plt.imshow(data[i].reshape(28,28))
        plt.xticks(())
        plt.yticks(())
    plt.tight_layout()

# %%
plot_mnist_image_matrix(X_digits,[3,8])

# %%
from sklearn.decomposition import PCA
pca = PCA()
X2_digits = pca.fit_transform(X_digits)

# %%
W = pca.components_
plot_mnist_image_matrix(W,[1,8])

# %% [markdown]
# Umm....huh?
#
# Think of this as visualizing the ranked *best mean* images. So components[0:10] are pretty clear...

# %%
plot_mnist_image_matrix(W,[1,10])

# %% [markdown]
# But components[100:] are mostly noise

# %%
#later ranked columns, less meaningful, showing us noise 
plot_mnist_image_matrix(W[100:],[1,10])

# %%
W = pca.components_

plot_mnist_image_matrix(W,[2,10])

# %% [markdown]
# We quantify this observation with the `explained_variance_` variable

# %%
#columns are ranked projects of the data as shown by the plot below

# %%
plt.plot(pca.explained_variance_ratio_);

# %% [markdown]
# We consider 784 components and we could comfortably reduce this to 100 with very little loss.

# %% [markdown]
# ##Don't believe me...I'll prove it!
# We will reconstruct the data set from this reduced projections.

# %%
#reconstruction from projection on 20 components
from sklearn.decomposition import PCA
pca = PCA(20)
X2_few_digits = pca.fit_transform(X_digits)

# %%
#reconstruction. we reduced down the dimensions quite an bit and still recovered the signal
plt.figure(figsize=(16,4))
X_recons_digits = pca.inverse_transform(X2_few_digits)
plot_mnist_image_matrix(X_recons_digits,[2,8])

# %%
plot_mnist_image_matrix(X_digits,[2,2])

# %%
plot_mnist_image_matrix(X_recons_digits,[2,8])

# %% [markdown]
# EXIT_SUCCESS;

# %% [markdown]
# - What happens, when you multiply one of the data axis with a large (or small) number?
#
#   Does the result stay the same? Why/why not?
#
# -----
#
# - Try to explore the iris dataset below using PCA.
#
#   What happens if you visualize the *last* two components of PCA instead of the first two?
#
# -----
#
# - Use PCA with 1, 2 or 3 axes and reconstruct the Iris data from each. How do the results change?

# %%
from sklearn import datasets
_,data,target,_,_ = datasets.load_iris().values()

# %%
data
# Out:
# array([[ 7. ,  3.2,  4.7,  1.4],
#        [ 6.6,  3. ,  4.4,  1.4],
#        [ 5.5,  2.6,  4.4,  1.2],
#        [ 5. ,  3.4,  1.5,  0.2],
#        [ 5.5,  2.3,  4. ,  1.3],
#        [ 7.2,  3.6,  6.1,  2.5],
#        [ 6.1,  3. ,  4.6,  1.4],
#        [ 7.2,  3. ,  5.8,  1.6],
#        [ 5.1,  3.5,  1.4,  0.2],
#        [ 6.9,  3.1,  4.9,  1.5],
#        [ 7.6,  3. ,  6.6,  2.1],
#        [ 5.8,  2.7,  4.1,  1. ],
#        [ 5.8,  2.7,  5.1,  1.9],
#        [ 6.5,  3.2,  5.1,  2. ],
#        [ 6.9,  3.1,  5.4,  2.1],
#        [ 6.2,  2.9,  4.3,  1.3],
#        [ 5.2,  4.1,  1.5,  0.1],
#        [ 6.8,  3.2,  5.9,  2.3],
#        [ 6.7,  2.5,  5.8,  1.8],
#        [ 5.1,  3.4,  1.5,  0.2],
#        [ 5. ,  3.5,  1.6,  0.6],
#        [ 6.5,  3. ,  5.8,  2.2],
#        [ 7.4,  2.8,  6.1,  1.9],
#        [ 5.1,  2.5,  3. ,  1.1],
#        [ 6.9,  3.1,  5.1,  2.3],
#        [ 5.4,  3.9,  1.7,  0.4],
#        [ 5.7,  2.5,  5. ,  2. ],
#        [ 6.3,  2.7,  4.9,  1.8],
#        [ 4.9,  2.5,  4.5,  1.7],
#        [ 5.8,  4. ,  1.2,  0.2],
#        [ 5.6,  2.7,  4.2,  1.3],
#        [ 6. ,  2.2,  5. ,  1.5],
#        [ 4.3,  3. ,  1.1,  0.1],
#        [ 5.5,  4.2,  1.4,  0.2],
#        [ 5. ,  3.3,  1.4,  0.2],
#        [ 6.8,  3. ,  5.5,  2.1],
#        [ 7.7,  3. ,  6.1,  2.3],
#        [ 4.5,  2.3,  1.3,  0.3],
#        [ 4.6,  3.2,  1.4,  0.2],
#        [ 6.2,  2.8,  4.8,  1.8],
#        [ 6.7,  3.3,  5.7,  2.1],
#        [ 5.7,  3. ,  4.2,  1.2],
#        [ 5. ,  2.3,  3.3,  1. ],
#        [ 5.6,  2.5,  3.9,  1.1],
#        [ 5.6,  2.8,  4.9,  2. ],
#        [ 4.9,  3.1,  1.5,  0.1],
#        [ 6. ,  2.9,  4.5,  1.5],
#        [ 6.4,  3.2,  5.3,  2.3],
#        [ 6.4,  2.8,  5.6,  2.2],
#        [ 4.9,  3. ,  1.4,  0.2],
#        [ 6.8,  2.8,  4.8,  1.4],
#        [ 4.9,  3.1,  1.5,  0.1],
#        [ 6.5,  3. ,  5.5,  1.8],
#        [ 6.3,  3.3,  6. ,  2.5],
#        [ 4.4,  3. ,  1.3,  0.2],
#        [ 4.8,  3. ,  1.4,  0.3],
#        [ 5.8,  2.6,  4. ,  1.2],
#        [ 6.2,  2.2,  4.5,  1.5],
#        [ 6.9,  3.2,  5.7,  2.3],
#        [ 6.3,  3.3,  4.7,  1.6],
#        [ 5.7,  2.8,  4.1,  1.3],
#        [ 6.7,  3. ,  5.2,  2.3],
#        [ 6.7,  3.1,  5.6,  2.4],
#        [ 4.7,  3.2,  1.6,  0.2],
#        [ 5.7,  2.8,  4.5,  1.3],
#        [ 6.3,  2.5,  5. ,  1.9],
#        [ 6.3,  2.9,  5.6,  1.8],
#        [ 5.5,  2.4,  3.7,  1. ],
#        [ 5.4,  3.4,  1.7,  0.2],
#        [ 5.9,  3. ,  4.2,  1.5],
#        [ 7.2,  3.2,  6. ,  1.8],
#        [ 7.3,  2.9,  6.3,  1.8],
#        [ 5.8,  2.7,  5.1,  1.9],
#        [ 6.7,  3.1,  4.4,  1.4],
#        [ 6.6,  2.9,  4.6,  1.3],
#        [ 5.7,  2.9,  4.2,  1.3],
#        [ 5.4,  3.7,  1.5,  0.2],
#        [ 7.7,  2.8,  6.7,  2. ],
#        [ 6.1,  3. ,  4.9,  1.8],
#        [ 5.6,  2.9,  3.6,  1.3],
#        [ 4.6,  3.6,  1. ,  0.2],
#        [ 5.6,  3. ,  4.5,  1.5],
#        [ 4.6,  3.1,  1.5,  0.2],
#        [ 6.1,  2.8,  4. ,  1.3],
#        [ 6.1,  2.6,  5.6,  1.4],
#        [ 5.1,  3.8,  1.6,  0.2],
#        [ 5.2,  3.5,  1.5,  0.2],
#        [ 5.3,  3.7,  1.5,  0.2],
#        [ 6.3,  2.5,  4.9,  1.5],
#        [ 5.7,  4.4,  1.5,  0.4],
#        [ 5.7,  2.6,  3.5,  1. ],
#        [ 4.9,  2.4,  3.3,  1. ],
#        [ 6. ,  2.2,  4. ,  1. ],
#        [ 7.7,  2.6,  6.9,  2.3],
#        [ 6.7,  3.3,  5.7,  2.5],
#        [ 5.9,  3. ,  5.1,  1.8],
#        [ 6.4,  3.2,  4.5,  1.5],
#        [ 5.4,  3.4,  1.5,  0.4],
#        [ 6.5,  2.8,  4.6,  1.5],
#        [ 6.3,  2.8,  5.1,  1.5],
#        [ 6.7,  3. ,  5. ,  1.7],
#        [ 4.8,  3.1,  1.6,  0.2],
#        [ 5.5,  2.5,  4. ,  1.3],
#        [ 5. ,  3.5,  1.3,  0.3],
#        [ 5.7,  3.8,  1.7,  0.3],
#        [ 5. ,  2. ,  3.5,  1. ],
#        [ 6.7,  3.1,  4.7,  1.5],
#        [ 5. ,  3.4,  1.6,  0.4],
#        [ 5.1,  3.8,  1.5,  0.3],
#        [ 4.8,  3.4,  1.6,  0.2],
#        [ 5.5,  3.5,  1.3,  0.2],
#        [ 5. ,  3. ,  1.6,  0.2],
#        [ 5.2,  2.7,  3.9,  1.4],
#        [ 5.1,  3.3,  1.7,  0.5],
#        [ 5.4,  3.9,  1.3,  0.4],
#        [ 7.1,  3. ,  5.9,  2.1],
#        [ 5.8,  2.7,  3.9,  1.2],
#        [ 7.7,  3.8,  6.7,  2.2],
#        [ 5.1,  3.7,  1.5,  0.4],
#        [ 6.1,  2.8,  4.7,  1.2],
#        [ 5.4,  3. ,  4.5,  1.5],
#        [ 5.2,  3.4,  1.4,  0.2],
#        [ 6.3,  3.4,  5.6,  2.4],
#        [ 4.4,  2.9,  1.4,  0.2],
#        [ 5.6,  3. ,  4.1,  1.3],
#        [ 6.3,  2.3,  4.4,  1.3],
#        [ 5. ,  3.6,  1.4,  0.2],
#        [ 6.1,  2.9,  4.7,  1.4],
#        [ 6.5,  3. ,  5.2,  2. ],
#        [ 6.4,  2.9,  4.3,  1.3],
#        [ 4.4,  3.2,  1.3,  0.2],
#        [ 5.8,  2.8,  5.1,  2.4],
#        [ 4.6,  3.4,  1.4,  0.3],
#        [ 6.4,  2.7,  5.3,  1.9],
#        [ 4.9,  3.1,  1.5,  0.1],
#        [ 7.9,  3.8,  6.4,  2. ],
#        [ 5.9,  3.2,  4.8,  1.8],
#        [ 5.5,  2.4,  3.8,  1.1],
#        [ 5. ,  3.2,  1.2,  0.2],
#        [ 6. ,  3. ,  4.8,  1.8],
#        [ 6. ,  3.4,  4.5,  1.6],
#        [ 4.8,  3. ,  1.4,  0.1],
#        [ 4.7,  3.2,  1.3,  0.2],
#        [ 4.8,  3.4,  1.9,  0.2],
#        [ 5.1,  3.8,  1.9,  0.4],
#        [ 6. ,  2.7,  5.1,  1.6],
#        [ 6.4,  3.1,  5.5,  1.8],
#        [ 6.4,  2.8,  5.6,  2.1],
#        [ 5.1,  3.5,  1.4,  0.3],
#        [ 6.2,  3.4,  5.4,  2.3]])

# %%
pca = PCA(3)
data_E = pca.fit_transform(data)
print data_E[:10,:]
# Out:
# [[-1.2848 -0.6854 -0.4061]
#  [-0.8996 -0.3296 -0.3148]
#  [-0.463   0.6695 -0.0241]
#  [ 2.6265 -0.1704 -0.0158]
#  [-0.181   0.8256 -0.1771]
#  [-2.9181 -0.7804  0.4217]
#  [-0.8902  0.0338 -0.0098]
#  [-2.3876 -0.4625 -0.452 ]
#  [ 2.6842 -0.3266 -0.0215]
#  [-1.4641 -0.5042 -0.3383]]

# %%
X_reconstructed = pca.inverse_transform(data_E)
for i in xrange(4):
    for j in xrange(4):
        plt.subplot(4, 4, i * 4 + j + 1)
        plt.scatter(data[:,i], data[:,j],c='r')
        plt.scatter(X_reconstructed[:,i], X_reconstructed[:,j],c='b')
        plt.axis('equal')

# %%
plt.scatter(data_E[:,0], data_E[:,1])
